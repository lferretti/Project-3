# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key
import nltk
import time
import pandas as pd
import nltk
# nltk.download('vader_lexicon')

# from vaderSentiment import SentimentIntensityAnalyzer
# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer #as SIA


url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

analyser = SentimentIntensityAnalyzer()

# %%
# Search for articles that mention granola
query = "stocks"

# %%
# Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=ElPKhSQkjeT9c2Wd&q=stocks'

# %%
news1=[]
query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?page=1&q=finance&fq=news_desk:("business" "politics" "financial")&begin_date=20180101&end_date=20181231&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""

articles = requests.get(query_url).json()
articles_list = [article for article in articles["response"]["docs"]]
for article in articles_list:
    news1.append([article["pub_date"], article["abstract"]])

pprint(news1)
# Out:
# [['2018-12-17T11:00:04+0000',
#   'Our columnist got quite a surprise when he sent out a query asking people '
#   'to talk to him about talking about money.'],
#  ['2018-12-19T15:44:32+0000',
#   'The Fed is widely expected to raise rates at the conclusion of its two-day '
#   'meeting on Wednesday. But all eyes are on what happens next.'],
#  ['2018-12-18T00:01:18+0000',
#   'The Malaysian government filed charges against Goldman Sachs for its role '
#   'in the 1MDB fraud, and in the United States, the bank’s lawyers held talks '
#   'with federal prosecutors.'],
#  ['2018-12-19T19:01:16+0000',
#   'Jerome H. Powell, the Fed chairman, defended the decision to raise the '
#   'benchmark rate for the fifth consecutive quarter, a move made despite '
#   'political pressure and financial market worries.'],
#  ['2018-12-18T15:00:28+0000',
#   'The United States has the opportunity to incubate technologies that could '
#   'enable a digital transnational currency of the future.'],
# ...

# %%
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=Dh6471Ixs0w5lLHv5ASWnIsiyiwU0fD0&q=stocks

# fq=news_desk:("Sports" "Foreign") 



# query_url = "https://api.nytimes.com/svc/archive/v1/2019/1.json?q=stocks&api-key=Dh6471Ixs0w5lLHv5ASWnIsiyiwU0fD0"
    
# query_url = """https://api.nytimes.com/svc/archive/v1/2018/1.json?q=finance&fq=news_desk.contains:("business" "politics" "financial")&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
    
# articlesearch.json?q=finance&fq=news_desk.contains:("business" "politics" "financial")&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
    
i=0
date = []
t = []
abstract = []
news = []
articles_list = []
while (i<101):
    query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=finance&fq=news_desk:("business" "politics" "financial")&page="""+str(i)+"""&begin_date=20180101&end_date=20180630&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     print(query_url)
    articles = requests.get(query_url).json()
    articles_list = [article for article in articles["response"]["docs"]]
    for article in articles_list:
        news.append([article["pub_date"], article["abstract"]])
        date.append(article["pub_date"].split("T")[0])
        t.append(article["pub_date"].split("T")[1])
        abstract.append(article["abstract"])
    i= i+1
    time.sleep(6)

j=0
while (j<101):
    query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=finance&fq=news_desk:("business" "politics" "financial")&page="""+str(j)+"""&begin_date=20180701&end_date=20181231&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     print(query_url)
    articles = requests.get(query_url).json()
    articles_list = [article for article in articles["response"]["docs"]]
    for article in articles_list:
        news.append([article["pub_date"], article["abstract"]])
        date.append(article["pub_date"].split("T")[0])
        t.append(article["pub_date"].split("T")[-1])
        abstract.append(article["abstract"])
    j= j+1
    time.sleep(6)
    
pprint(news)
# Out:
# [['2018-06-27T22:10:42+0000',
#   'Regulators are clamping down on the credit bureau in the aftermath of the '
#   'breach, which left 147 million people vulnerable.'],
#  ['2018-06-26T23:04:45+0000',
#   'The Wall Street bank is betting its brokerage business can help drive '
#   'growth. Mary Schapiro, who led the S.E.C. from 2009 to 2012, may be a '
#   'guide.'],
#  ['2018-06-29T19:40:15+0000',
#   'Some of the biggest lenders are paying out more than 100 percent of their '
#   'expected profits.'],
#  ['2018-06-29T11:56:55+0000',
#   'The Fed’s tests of the big banks produced some clear winners and losers. '
#   'Deutsche Bank fared worst.'],
#  ['2018-06-28T20:30:08+0000',
#   'The Federal Reserve gave clean bills of health to top banks, but told '
#   'Goldman Sachs and Morgan Stanley to freeze shareholder payouts at last '
#   'year’s levels.'],
#  ['2018-06-27T23:30:51+0000',
#   'The German lender, already in regulators’ bad books, may struggle to pass '
# ...

# %%
news2 = pd.DataFrame(news)
# news2.rename(columns={0: "Datetime", 1:"abstract"})
news2
# df.rename(columns={"A": "a", "B": "c"})
# Out:
#                              0  \
# 0     2018-06-27T22:10:42+0000
# 1     2018-06-26T23:04:45+0000
# 2     2018-06-29T19:40:15+0000
# 3     2018-06-29T11:56:55+0000
# 4     2018-06-28T20:30:08+0000
# ...                        ...
# 1072  2018-11-05T11:40:59+0000
# 1073  2018-11-13T11:45:41+0000
# 1074  2018-11-30T11:31:18+0000
# 1075  2018-10-25T10:20:07+0000
# 1076  2018-12-20T19:47:53+0000
#
#                                                       1
# 0     Regulators are clamping down on the credit bur...
# 1     The Wall Street bank is betting its brokerage ...
# 2     Some of the biggest lenders are paying out mor...
# 3     The Fed’s tests of the big banks produced some...
# 4     The Federal Reserve gave clean bills of health...
# ...                                                 ...
# 1072  Masa Son says that the company has “a responsi...
# 1073  The company has gobbled up leases for so much ...
# 1074  On the sidelines of the Group of 20 meeting in...
# ...

# %%
news3 = pd.DataFrame({
                    'date': date,
                    'time':t,
                    'abstract':abstract})
news3
# Out:
#             date           time  \
# 0     2018-06-27  22:10:42+0000
# 1     2018-06-26  23:04:45+0000
# 2     2018-06-29  19:40:15+0000
# 3     2018-06-29  11:56:55+0000
# 4     2018-06-28  20:30:08+0000
# ...          ...            ...
# 1072  2018-11-05  11:40:59+0000
# 1073  2018-11-13  11:45:41+0000
# 1074  2018-11-30  11:31:18+0000
# 1075  2018-10-25  10:20:07+0000
# 1076  2018-12-20  19:47:53+0000
#
#                                                abstract
# 0     Regulators are clamping down on the credit bur...
# 1     The Wall Street bank is betting its brokerage ...
# 2     Some of the biggest lenders are paying out mor...
# 3     The Fed’s tests of the big banks produced some...
# 4     The Federal Reserve gave clean bills of health...
# ...                                                 ...
# 1072  Masa Son says that the company has “a responsi...
# 1073  The company has gobbled up leases for so much ...
# 1074  On the sidelines of the Group of 20 meeting in...
# ...

# %%
def sentiment_analyzer_scores(news):
    sentiment = []
    for sentence in news["abstract"]:
        score = analyser.polarity_scores(sentence)
        sentiment.append(score)
    return sentiment
#     print("{:-<40} {}".format(sentence, str(score)))

# %%
news3["sentiment_score"] = sentiment_analyzer_scores(news3)
news3["date"] = pd.to_datetime(news3["date"])
print(type(news3['date'][0]))
news3.sort_values(by='date')

# news2["sentiment_score"]
news3
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#            date           time  \
# 0    2018-06-27  22:10:42+0000
# 1    2018-06-26  23:04:45+0000
# 2    2018-06-29  19:40:15+0000
# 3    2018-06-29  11:56:55+0000
# 4    2018-06-28  20:30:08+0000
# ...         ...            ...
# 1072 2018-11-05  11:40:59+0000
# 1073 2018-11-13  11:45:41+0000
# 1074 2018-11-30  11:31:18+0000
# 1075 2018-10-25  10:20:07+0000
# 1076 2018-12-20  19:47:53+0000
#
#                                                abstract  \
# 0     Regulators are clamping down on the credit bur...
# 1     The Wall Street bank is betting its brokerage ...
# 2     Some of the biggest lenders are paying out mor...
# 3     The Fed’s tests of the big banks produced some...
# 4     The Federal Reserve gave clean bills of health...
# ...                                                 ...
# 1072  Masa Son says that the company has “a responsi...
# 1073  The company has gobbled up leases for so much ...
# ...

# %%
type(news3)
news2.to_csv("test.csv")

# %%
news3.to_csv("sentiment_analysis-2018finance.csv")
# Users⁩ ▸ ⁨jasonree⁩ ▸ ⁨Documents⁩ ▸ ⁨GitHub⁩ ▸ ⁨Project-3⁩
