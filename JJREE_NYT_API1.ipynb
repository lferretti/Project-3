# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key
import nltk
import time
import pandas as pd
import nltk
# nltk.download('vader_lexicon')

# from vaderSentiment import SentimentIntensityAnalyzer
# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer #as SIA


url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

analyser = SentimentIntensityAnalyzer()

# %%
# Search for articles that mention granola
query = "stocks"

# %%
# Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=ElPKhSQkjeT9c2Wd&q=stocks'

# %%
news1=[]
query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?page=1&q=finance&fq=news_desk:("business" "politics" "financial")&begin_date=20180101&end_date=20181231&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""

articles = requests.get(query_url).json()
articles_list = [article for article in articles["response"]["docs"]]
for article in articles_list:
    news1.append([article["pub_date"], article["abstract"]])

pprint(news1)
# Out:
# [['2018-12-17T11:00:04+0000',
#   'Our columnist got quite a surprise when he sent out a query asking people '
#   'to talk to him about talking about money.'],
#  ['2018-12-19T15:44:32+0000',
#   'The Fed is widely expected to raise rates at the conclusion of its two-day '
#   'meeting on Wednesday. But all eyes are on what happens next.'],
#  ['2018-12-18T00:01:18+0000',
#   'The Malaysian government filed charges against Goldman Sachs for its role '
#   'in the 1MDB fraud, and in the United States, the bank’s lawyers held talks '
#   'with federal prosecutors.'],
#  ['2018-12-19T19:01:16+0000',
#   'Jerome H. Powell, the Fed chairman, defended the decision to raise the '
#   'benchmark rate for the fifth consecutive quarter, a move made despite '
#   'political pressure and financial market worries.'],
#  ['2018-12-18T15:00:28+0000',
#   'The United States has the opportunity to incubate technologies that could '
#   'enable a digital transnational currency of the future.'],
#  ['2018-12-17T00:51:02+0000',
#   'Now that the supermarket tabloid has admitted to prosecutors that it did '
#   'political dirty work for Donald Trump, here’s a look at its unlikely '
#   'power.'],
#  ['2018-12-14T16:54:11+0000',
#   'We define immediate annuities, fixed annuities, variable annuities and '
#   'index annuities, plus give you questions to ask salespeople. '],
#  ['2018-12-14T16:30:28+0000',
#   'Mortgage lenders are again promoting more complicated loans, which offer '
#   'benefits for wealthy borrowers but come with big drawbacks.'],
#  ['2018-12-13T15:16:04+0000',
#   'The end of the so-called quantitative easing effort is a milestone for the '
#   'euro and a signal that the European Central Bank is confident enough in the '
#   'eurozone’s health.'],
#  ['2018-12-11T10:00:09+0000',
#   'While Elizabeth Warren and Bernie Sanders would likely disavow super PACs, '
#   'candidates from donor-rich states like New York and California would face a '
#   'vexing choice and risk alienating liberals.']]

# %%
i=0
date = []
t = []
abstract = []
news = []
articles_list = []
while (i<101):
    query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=politics&fq=news_desk:("business" "politics" "financial")&page="""+str(i)+"""&begin_date=20180101&end_date=20180630&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=finance&fq=news_desk:("business" "politics" "financial")&page="""+str(i)+"""&begin_date=20180101&end_date=20180630&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     print(query_url)
    articles = requests.get(query_url).json()
    articles_list = [article for article in articles["response"]["docs"]]
    for article in articles_list:
        news.append([article["pub_date"], article["abstract"]])
        date.append(article["pub_date"].split("T")[0])
        t.append(article["pub_date"].split("T")[1])
        abstract.append(article["abstract"])
    i= i+1
    time.sleep(6)

j=0
while (j<101):
    query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=politics&fq=news_desk:("business" "politics" "financial")&page="""+str(j)+"""&begin_date=20180701&end_date=20181231&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     query_url = """https://api.nytimes.com/svc/search/v2/articlesearch.json?q=finance&fq=news_desk:("business" "politics" "financial")&page="""+str(j)+"""&begin_date=20180701&end_date=20181231&api-key=DIsZ9hmtxpVeNzaY73EbuvWxkHyPAggk"""
#     print(query_url)
    articles = requests.get(query_url).json()
    articles_list = [article for article in articles["response"]["docs"]]
    for article in articles_list:
        news.append([article["pub_date"], article["abstract"]])
        date.append(article["pub_date"].split("T")[0])
        t.append(article["pub_date"].split("T")[-1])
        abstract.append(article["abstract"])
    j= j+1
    time.sleep(6)
    
pprint(news)
# Out:
# [['2018-06-21T22:16:45+0000',
#   'Glitchy enforcement of a new Facebook political ad policy is creating '
#   'headaches for small businesses, news publishers, and other advertisers.'],
#  ['2018-06-22T13:00:01+0000',
#   'This week, tech companies weighed in on the separation of children from '
#   'their migrant parents at the Mexico border. Here’s why tech has become more '
#   'activist.'],
#  ['2018-06-14T23:49:16+0000',
#   'The company introduced new policies in response to criticism of its role in '
#   'the 2016 election, but news outlets say journalism can now be mislabeled '
#   'political content.'],
#  ['2018-06-29T18:15:00+0000',
#   'Calls to eliminate the agency charged with enforcing immigration laws, '
#   'mostly rooted on the political fringe, have gained traction among '
#   'progressive candidates.'],
#  ['2018-06-27T09:00:14+0000',
#   'It was a night of rebellious Democrats, who backed progressive insurgents, '
#   'and loyal Republicans, who helped incumbents backed by President Trump '
#   'persevere.'],
#  ['2018-06-27T01:17:18+0000',
#   'The president helped lift South Carolina’s governor and a House candidate '
#   'in New York, and the Democrats’ liberal wing had its biggest wins yet'],
#  ['2018-06-29T00:36:11+0000',
#   'Few issues are as rooted in the political culture of Republicans as the '
#   'Supreme Court. They hope for a big boost in the midterms.'],
#  ['2018-06-15T19:41:40+0000',
#   'A survey shows a sharp partisan split in consumer confidence. But a third '
#   'of Democrats say President Trump deserves some credit for economic gains.'],
#  ['2018-06-27T14:21:09+0000',
#   'The ruling could cost public-sector unions more than a million members. But '
#   'the ones who stay could make labor more powerful.'],
#  ['2018-06-26T21:11:34+0000',
#   'The president tweeted something untrue about Representative Maxine Waters. '
#   'Outrage ensued online, but that only helped spread disinformation.'],
#  ['2018-06-28T01:13:24+0000',
#   'Democrats will focus on Justice Kennedy’s replacement in an attempt to '
#   'motivate voters in the fall, while conservatives will pressure vulnerable '
#   'Democratic senators in red states.'],
#  ['2018-06-26T09:00:01+0000',
#   'In New York, establishment candidates face tough challenges. In Utah, Mitt '
#   'Romney is back. President Trump has weighed in on South Carolina’s runoff '
#   'for governor.'],
#  ['2018-06-26T17:27:46+0000',
#   'The refusal by Senate Republicans to act on President Obama’s nomination of '
#   'Merrick Garland to the Supreme Court, paving the way for Justice Gorsuch, '
#   'reverberated powerfully after Tuesday’s rulings.'],
#  ['2018-06-30T16:59:57+0000',
#   'The looming battle over the Supreme Court opening highlights the fissure '
#   'between establishment Democrats and activists pressing a liberal, '
#   'anti-Trump agenda.'],
#  ['2018-06-27T23:54:35+0000',
#   'The stunning primary defeat of Representative Joseph Crowley by a young '
#   'Latina progressive raised the pressure on the Democrats’ aging leadership '
#   'to step aside for a new generation.'],
#  ['2018-06-27T04:01:47+0000',
#   'Mr. Grimm, a former congressman who pleaded guilty to tax fraud, tried to '
#   'make a comeback for his old House seat. It didn’t work. “We make plans,” he '
#   'said Tuesday night. “God laughs at us.”'],
#  ['2018-06-24T16:30:43+0000',
#   'While their goals like a higher minimum wage and “Medicare for All” have '
#   'gained traction among Democrats, Senator Sanders and his allies have '
#   'struggled to win elections.'],
#  ['2018-06-24T02:52:32+0000',
#   'Ms. Warren and President Trump were both campaigning for Senate candidates '
#   'in Nevada Saturday, but their fast-burning exchange had the feel of a 2020 '
#   'presidential campaign confrontation.'],
#  ['2018-06-29T19:15:20+0000',
#   'The automaker said, in a filing with the Commerce Department, that new '
#   'trade barriers “could lead to a smaller G.M.”'],
#  ['2018-06-26T22:55:28+0000',
#   'President Trump signaled his support for using an existing committee that '
#   'reviews risky foreign investments for national security threats.'],
#  ['2018-06-25T22:49:20+0000',
#   'A new version of the 1040 income tax form, set for release this week, omits '
#   'some popular deductions and requires several worksheets for many taxpayers '
#   'to complete.'],
#  ['2018-06-23T09:00:07+0000',
#   'Five years ago, the Supreme Court struck down a key part of the landmark '
#   'Voting Rights Act. Since then, Alabama has enacted a slew of restrictive '
#   'voting laws and policies.'],
#  ['2018-06-23T15:00:12+0000',
#   'With the president’s approval rating at 90 percent among Republicans, many '
#   'supporters say they defend Mr. Trump even with some misgivings because they '
#   'feel criticism of him is constantly overblown.'],
#  ['2018-06-22T13:57:11+0000',
#   'The president dispensed political clemency to Martha Roby, who had been '
#   'critical of him, and endorsed Ron DeSantis in the Florida gubernatorial '
#   'primary'],
#  ['2018-06-13T22:12:23+0000',
#   'The vice president’s appearance at a large convention of evangelical '
#   'pastors drew effusive praise from many attendees, but others complained it '
#   'was overtly political.'],
#  ['2018-06-24T23:25:00+0000',
#   'With other countries raising tariffs to American products and signing trade '
#   'deals without the United States, the American cheesemaker is increasingly '
#   'standing alone.'],
#  ['2018-06-20T17:05:43+0000',
#   'Mr. Bloomberg plans to pour money into advertising on television, online '
#   'and in the mail, with most of it going to support Democratic congressional '
#   'candidates.'],
#  ['2018-06-21T09:00:13+0000',
#   'The Texas senator, facing a serious re-election challenge, is projecting '
#   'loyalty to a president he once criticized as erratic and dangerous.'],
#  ['2018-06-22T23:41:57+0000',
#   'The Trump administration has begun granting a handful of exclusions from '
#   'its steel and aluminum tariffs, but the slow, opaque process still has '
#   'nearly 20,000 applications waiting.'],
#  ['2018-06-20T14:54:11+0000',
#   'Conservative Christians are navigating a tricky path as they recoil at an '
#   'immigration policy enacted by a president they support.'],
#  ['2018-06-19T22:40:46+0000',
#   'The decision is a gamble that President Trump can lift Gov. Henry McMaster, '
#   'one of Mr. Trump’s earliest supporters, to the Republican nomination at the '
#   'last minute.'],
#  ['2018-06-21T00:34:39+0000',
#   'In border states, Republican voters say that whatever sympathy they feel '
#   'for children separated from parents is complicated by frustration over the '
#   'flow of undocumented immigrants from Mexico.'],
#  ['2018-06-20T22:19:34+0000',
#   'Accelerating growth has given the administration more leverage over trading '
#   'partners. But economists warn of potential headwinds beyond this year.'],
#  ['2018-06-19T23:08:38+0000',
#   'The president, the attorney general and the secretary of homeland security '
#   'have used lots of figures and interpretations of recent history to explain '
#   'recent policy changes. Not all of it has been accurate.'],
#  ['2018-06-19T00:10:34+0000',
#   'Mr. Trump’s anti-immigrant remarks are aimed at the conservative base of '
#   'the party, especially those in red states, at a time when the party’s '
#   'pragmatist wing has been diminished.'],
#  ['2018-06-18T09:00:07+0000',
#   'Ms. Valdez is a Latina, a lesbian and the Democratic nominee for governor. '
#   'But some activists on the left say she’s not worthy of their support, '
#   'particularly because of her record on immigration.'],
#  ['2018-06-17T17:10:19+0000',
#   'An estimated 1,000 young women took part in sessions like “How Political '
#   'Correctness Is Making Everyone Stupid” and displayed enthusiasm they hope '
#   'to see for Republicans in the midterm elections.'],
#  ['2018-06-17T12:00:04+0000',
#   'Mr. Stewart, a Minnesota transplant who has defended the Confederacy and '
#   'praised white nationalists, has seized opportunities to gain media '
#   'attention, especially with harsh remarks about immigrants.'],
#  ['2018-06-16T15:06:41+0000',
#   'The newspaper that serves as the Chinese Communist Party’s mouthpiece, and '
#   'other state-controlled outlets, had harsh words for the president’s tariff '
#   'move.'],
#  ['2018-06-15T12:15:02+0000',
#   'The tariffs on China by the Trump administration shift what has primarily '
#   'been a war of words between Washington and Beijing into a full-blown trade '
#   'war.'],
#  ['2018-06-14T09:00:13+0000',
#   'Protests of conservatives speakers at colleges have prompted new policies '
#   'that penalize disruptions, putting academia on the front lines of the '
#   'left-right culture wars.'],
#  ['2018-06-15T18:48:11+0000',
#   'The dismissal of Rob Rogers, the longtime editorial cartoonist and a '
#   'frequent critic of President Trump, was the latest controversy involving '
#   'the paper’s editorial page.'],
#  ['2018-06-15T14:21:33+0000',
#   'The president’s partner in Dubai has tapped a company controlled by the '
#   'government in Beijing to help build a project featuring an 18-hole course '
#   'designed by Tiger Woods.'],
#  ['2018-06-14T00:21:26+0000',
#   'After a series of contests in which loyalty to President Trump was a clear '
#   'litmus test to voters, Republicans are reckoning with his transformation of '
#   'the party.'],
#  ['2018-06-12T15:08:31+0000',
#   'Organizing for Action, the political group launched by Barack Obama, will '
#   'deploy and train volunteers in more than two dozen Republican-held '
#   'congressional districts.'],
#  ['2018-06-13T21:00:07+0000',
#   'Archie Parnell won Tuesday’s primary despite admitting to abusing the woman '
#   'who is now his ex-wife in the 1970s.'],
#  ['2018-06-13T01:02:58+0000',
#   'Mark Sanford, a frequent critic of the president, was ousted from his South '
#   'Carolina House seat, while a firebrand Trump supporter won a Senate bid in '
#   'Virginia.'],
#  ['2018-06-13T03:48:44+0000',
#   'The Times said that it was reviewing Ali Watkins’s involvement in the case, '
#   'including her relationship with James Wolfe, a former Senate Intelligence '
#   'Committee aide.'],
#  ['2018-06-13T23:25:38+0000',
#   'The United States, Saudi Arabia and Russia see common cause in tamping down '
#   'oil prices and boosting production — at least for now.'],
#  ['2018-06-13T09:00:09+0000',
#   'Virginia Republicans voted for Corey Stewart. South Carolina decided it was '
#   'done with Mark Sanford. And Democrats spurned insurgents from the activist '
#   'left.'],
#  ['2018-06-05T15:09:09+0000',
#   'The billionaire industrialist has been a major patron of the arts and with '
#   'his brother Charles guided the Americans for Prosperity conservative '
#   'agenda.'],
#  ['2018-06-10T15:26:29+0000',
#   'The Trump administration’s corporate tax cuts are unlikely to have their '
#   'promised effect on job creation, a trio of prominent economists has '
#   'concluded.'],
#  ['2018-06-01T23:20:23+0000',
#   'While voters get ready for California’s primary on June 5, Silicon Valley’s '
#   'tech community — which had been politically outspoken — has tried to stay '
#   'largely under the radar.'],
#  ['2018-06-01T16:58:46+0000',
#   'Coming on the heels of Martin Luther King Jr.’s death, it fueled a general '
#   'sense that the normal rules and constants of politics could no longer be '
#   'counted on.'],
#  ['2018-06-08T20:32:09+0000',
#   'The heart of Reagan Country may not love President Trump. But many there '
#   'think state Democrats have badly overreached and want to check their '
#   'power.'],
#  ['2018-06-07T17:13:36+0000',
#   'Liz and Dick Uihlein, founders of the shipping supply giant Uline, have '
#   'spent some $26 million this year alone, seeking to advance conservative '
#   'causes anywhere they can.'],
#  ['2018-06-06T19:00:58+0000',
#   'Mr. Nix’s statements to a Parliament committee contradicted some evidence '
#   'presented by a former employee, Christopher Wylie.'],
#  ['2018-06-06T23:26:17+0000',
#   'Internal documents revealed that corporations and trade groups were often '
#   'shut out of deliberations, breeding animosity between industry and a '
#   'supposedly business-friendly administration.'],
#  ['2018-06-06T11:00:05+0000',
#   'Trump voters can have long memories. Democratic voters in New Jersey have '
#   'not fully forgiven Senator Robert Menendez. And other points from the '
#   'night’s primaries.'],
#  ['2018-06-05T20:23:07+0000',
#   'President Trump called off a White House event set for Tuesday that was to '
#   'honor the winners of the 2018 Super Bowl. But only a few members of the '
#   'N.F.L. team were planning to attend in the first place. '],
#  ['2018-06-06T04:19:52+0000',
#   'The candidates, who edged out the former Los Angeles mayor Antonio '
#   'Villaraigosa, are likely to battle over President Trump this fall. '
#   'Democrats were in tight races in several Republican-held House districts.'],
#  ['2018-06-05T19:55:05+0000',
#   'China offered American officials the package in trade talks last weekend, '
#   'but the deal could quickly fizzle as the White House continues with its '
#   'plans to impose tariffs on the country.'],
#  ['2018-06-05T15:33:34+0000',
#   'The move came as the administration suggested it wants to split the Nafta '
#   'talks and negotiate separate agreements with Mexico and Canada.'],
#  ['2018-06-05T11:00:05+0000',
#   'There are 122 women on the primary ballots for congressional and statewide '
#   'executive offices this week.'],
#  ['2018-06-05T01:20:11+0000',
#   'On Monday, President Trump again took to Twitter to promote what he called '
#   'his accomplishments in office so far on immigration, the economy and North '
#   'Korea.'],
#  ['2018-06-03T23:04:42+0000',
#   'Measures to prevent election interference remain spotty, as shown in the '
#   'Fourth Congressional District’s Democratic primary.'],
#  ['2018-06-02T09:00:06+0000',
#   'The G.O.P.’s preferred candidates are running or winning in several states, '
#   'and potential problems have been averted. Some Republicans now see Senate '
#   'gains, not losses, in November.'],
#  ['2018-06-01T09:00:20+0000',
#   'Unexpectedly, President Trump has cut off the oxygen to the opposition, '
#   'insurgent wing of the Republican Party.'],
#  ['2018-05-31T09:00:11+0000',
#   'Bernie Sanders is holding live-streamed town hall events, while others have '
#   'started podcasts or even their own local news sites, bypassing traditional '
#   'media.'],
#  ['2018-05-31T13:44:01+0000',
#   'Tariffs on imported steel and aluminum are meant to fulfill President '
#   'Trump’s vows to protect American industry, but they are drawing a fierce '
#   'response.'],
#  ['2018-05-31T09:00:06+0000',
#   'In a survey, nearly three in four American adults said teachers’ salaries '
#   'were too low. The sentiment crossed party lines, even if raises meant '
#   'higher taxes.'],
#  ['2018-05-30T23:58:36+0000',
#   'President Trump must decide whether to go ahead with tariffs on allies like '
#   'the European Union, Canada and Mexico, whose temporary exemptions to the '
#   'tariffs expire Friday.'],
#  ['2018-05-30T00:25:39+0000',
#   'Mr. Parson differs little from the departing governor, Eric Greitens, in '
#   'terms of policy, but greatly in terms of political style and experience.'],
#  ['2018-05-29T19:38:54+0000',
#   'Rich and technologically advanced, the United States continues to accept a '
#   'degree of dysfunction that would be intolerable in any other rich society.'],
#  ['2018-05-29T07:00:05+0000',
#   'As women run for Congress and state offices this year, they want to '
#   'campaign and win on their own terms. Some are coming for their own party. '
#   'And many are not willing to wait.'],
#  ['2018-05-28T11:30:38+0000',
#   'The timing is likely a coincidence, experts say, but the moves have renewed '
#   'questions from critics about President Trump’s potential conflict of '
#   'interest.'],
#  ['2018-05-27T15:02:12+0000',
#   'As the primary approaches, Franklin Graham brings Jesus — and a '
#   'conservative political message — to a state with a vast pool of evangelical '
#   'voters.'],
#  ['2018-05-26T14:00:11+0000',
#   'The party and allied groups are spending more than $4 million on a handful '
#   'of chaotic congressional races that are critical to Democrats’ strategy to '
#   'win the House in November.'],
#  ['2018-05-22T17:17:40+0000',
#   'As the country heads for a time when no group makes up a majority, the '
#   'change may affect white attitudes in far more than racial and economic '
#   'matters.'],
#  ['2018-05-25T20:34:28+0000',
#   'The president aims to peel back labor protections and curb the power of '
#   'government unions, which assailed the actions.'],
#  ['2018-05-25T00:15:24+0000',
#   'Influential liberal donors and operatives are working with Never Trump '
#   'Republicans to blunt what they view as the president’s threat to '
#   'democracy.'],
#  ['2018-05-25T16:09:26+0000',
#   'The move would allow stalled trade negotiations with China to move forward, '
#   'but is also likely to provoke an intense backlash on Capitol Hill.'],
#  ['2018-05-25T13:30:05+0000',
#   'A federal incentive aimed at builders is at the center of a dispute over '
#   'whether public agencies can use it — and how they can pass it along.'],
#  ['2018-05-21T09:00:06+0000',
#   'Mrs. Clinton plans to endorse Andrew M. Cuomo for governor of New York this '
#   'week. But elsewhere on the 2018 campaign trail, she and Mr. Clinton are not '
#   'always welcome.'],
#  ['2018-05-24T22:55:47+0000',
#   'Economists, lawmakers and industry executives said the threat of tariffs on '
#   'imported cars threatened to undercut global economic growth and stoke trade '
#   'tensions even with crucial allies.'],
#  ['2018-05-23T15:07:53+0000',
#   'Ms. Abrams secured the Democratic nomination for governor of Georgia on '
#   'Tuesday evening. On Wednesday morning, she spoke to The New York Times '
#   'about what’s next.'],
#  ['2018-05-23T18:39:29+0000',
#   'The wind farms have increasingly become mainstream sources of power in '
#   'Northern Europe, but the United States has largely not pursued the '
#   'technology.'],
#  ['2018-05-23T00:06:56+0000',
#   'Ms. McGrath won without the backing of national Democrats. A viral video '
#   'about her military experience helped generate more than $1 million in '
#   'donations.'],
#  ['2018-05-22T17:40:17+0000',
#   'The president said that there had been no agreement to provide relief to '
#   'the Chinese telecom firm in return for trade concessions, though he left '
#   'the door open to a future pact.'],
#  ['2018-05-21T12:13:33+0000',
#   'Social media users noticed a distinct age gap between the Chinese delegates '
#   'and the American lawmakers who met them in Washington.'],
#  ['2018-05-19T23:44:14+0000',
#   'Ayanna Pressley is trying to become the first nonwhite member of the House '
#   'from Massachusetts, but Mr. Lewis and others have endorsed her white '
#   'opponent.'],
#  ['2018-05-19T18:45:28+0000',
#   'Stacey Abrams, a Democrat running for governor of Georgia, is trying to win '
#   'a statewide election in the Deep South without relying on '
#   'conservative-leaning white voters.'],
#  ['2018-05-19T18:25:13+0000',
#   'The two countries said they had reached an agreement to increase American '
#   'exports, but the White House noted that specifics would be agreed upon at a '
#   'later date.'],
#  ['2018-05-19T09:00:08+0000',
#   'Pennsylvania has had an all-male congressional delegation since 2015. After '
#   'victories by several women this week, that may change in November.'],
#  ['2018-05-18T19:13:49+0000',
#   'Chinese negotiators pledged to reduce tariffs and nontariff barriers on '
#   'American goods, a move that could result in an additional $200 billion of '
#   'purchases by 2020.'],
#  ['2018-05-18T00:14:47+0000',
#   'The idea of impeachment raises the stakes for control of Congress this '
#   'November and potentially puts the idea front and center in the midterm '
#   'elections.'],
#  ['2018-05-18T00:47:09+0000',
#   'The Trump administration had hoped a revised deal would reach the current '
#   'Congress, in which Republicans control both chambers. Now, those prospects '
#   'are diminishing by the day.'],
#  ['2018-05-14T16:14:20+0000',
#   'President Trump has not yet crafted a strategy for his involvement in the '
#   'midterms. So his supremely disciplined running mate has stepped into the '
#   'void.'],
#  ['2018-05-17T13:00:05+0000',
#   'Party officials want to resolve differences over the role and influence of '
#   'superdelegates, which were a major sticking point in the 2016 primaries.'],
#  ['2018-05-16T23:31:23+0000',
#   'At a Center for American Progress conference, Democrats who are potentially '
#   'eyeing 2020 focused less on opposing President Trump and more on '
#   'affirmative policy goals.'],
#  ['2018-05-16T09:00:18+0000',
#   'In Pennsylvania, the Democrats rallied around women, and the Republicans '
#   'went for candidates in the Trump mold.'],
#  ['2018-05-16T17:25:29+0000',
#   'Complete disengagement is impossible, but both Washington and Beijing '
#   'envision a day when they don’t need each other as much to power their '
#   'economies.'],
#  ['2018-05-16T11:53:35+0000',
#   'The Swiss pharmaceutical giant said Felix R. Ehrat would retire, after the '
#   'company said this month it had made payments to President Trump’s personal '
#   'lawyer.'],
#  ['2018-05-16T02:20:37+0000',
#   'Buoyed by a new congressional map and grass-roots anger at President Trump, '
#   'Democrats are poised to flip several Republican-held districts in a state '
#   'Mr. Trump narrowly won in 2016.'],
#  ['2018-05-15T13:21:41+0000',
#   'Voters on Tuesday cast ballots for primaries in four states: Idaho, '
#   'Nebraska, Oregon and Pennsylvania.'],
#  ['2018-05-15T19:05:11+0000',
#   'President Trump and congressional Republicans are reviving an enduring '
#   'party view that tying work requirements to antipoverty programs benefits '
#   'those in need. There’s little evidence that’s so.'],
#  ['2018-05-15T22:56:41+0000',
#   'Some of those testifying about the proposal commended the tariffs, and '
#   'others criticized them. But all agreed on the potential for the plan to '
#   'irrevocably alter the course of their businesses.'],
#  ['2018-05-15T15:21:55+0000',
#   'The president’s evangelical supporters are celebrating the new American '
#   'Embassy in Jerusalem as another policy promise he has made good on.'],
#  ['2018-05-14T19:48:03+0000',
#   'The state has a brand-new voting map, which analysts predict may help '
#   'Democrats eventually gain up to six seats in the House of Representatives '
#   'this fall.'],
#  ['2018-05-14T14:55:06+0000',
#   'The shift by the American president could ease tensions ahead of a visit to '
#   'Washington by Liu He, a vice premier in the Beijing government.'],
#  ['2018-05-14T09:00:06+0000',
#   'David Brody has unusual access to the president. In return, Mr. Trump gets '
#   'a direct line to the evangelical audience he depends on.'],
#  ['2018-05-14T06:00:03+0000',
#   'The National Retail Federation is planning an advertising blitz on “Fox & '
#   'Friends” to persuade Mr. Trump to back away from his tariffs plan.'],
#  ['2018-05-12T17:13:12+0000',
#   'The federal tax law had the unintended effect of giving states a tax '
#   'windfall. Now, states must weigh whether to spend the money or give it back '
#   'to residents.'],
#  ['2018-05-11T14:04:31+0000',
#   'In a companywide memo, Randall Stephenson also said the company’s head of '
#   'lobbying would retire.'],
#  ['2018-05-11T21:28:38+0000',
#   'F.B.I. agents are said to have interviewed people who worked with Mr. '
#   'Kurson at The Observer, the publication owned by the Kushner family, where '
#   'he served as editor.'],
#  ['2018-05-09T22:35:58+0000',
#   'The White House’s exultation over liberal men who resign over sexual '
#   'misconduct has grated politicians in both parties, who view President Trump '
#   'as a poor messenger on women’s rights.'],
#  ['2018-05-09T22:30:38+0000',
#   'After primaries in prime Trump territory Tuesday, Republicans were eager to '
#   'embrace the president while Democrats had a more delicate balancing act.'],
#  ['2018-05-09T17:20:30+0000',
#   'Robert Pittenger, seeking his fourth term, lost a primary challenge on '
#   'Tuesday to Mark Harris, a Baptist minister who opposes same-sex marriage.'],
#  ['2018-05-09T14:09:03+0000',
#   'Technology has come under the microscope in Washington. Here are the tools '
#   'that Cecilia Kang, who covers tech policy for The Times, uses to cover it.'],
#  ['2018-05-09T00:30:50+0000',
#   'The victory by Richard Cordray, who was endorsed by Senator Elizabeth '
#   'Warren of Massachusetts, came as a relief to many Democrats who saw Dennis '
#   'Kucinich as unelectable.'],
#  ['2018-05-09T02:13:25+0000',
#   'The former coal executive faced a concerted effort by Republicans to stop '
#   'him, including an appeal from President Trump. Patrick Morrisey, the '
#   'state’s attorney general, won the party’s nomination.'],
#  ['2018-05-07T13:40:05+0000',
#   'The president tweeted that Don Blankenship’s opponents have a better chance '
#   'of beating the incumbent Democratic senator, Joe Manchin.'],
#  ['2018-05-06T20:22:40+0000',
#   'The I.R.S. has started sending penalty notices to businesses that failed to '
#   'comply with the Affordable Care Act’s employer mandate, angering '
#   'Republicans and business groups.'],
#  ['2018-05-05T15:00:05+0000',
#   'Mr. McCain urged former Vice President Joseph R. Biden Jr. to “not walk '
#   'away” from politics, and said he wished he had chosen Joseph I. Lieberman, '
#   'not Sarah Palin, as his running mate in 2008.'],
#  ['2018-05-05T09:00:02+0000',
#   'Ohio’s newspapers backed Mike DeWine for the Republican nomination but were '
#   'divided over the two Democrats, Richard A. Cordray and Dennis Kucinich.'],
#  ['2018-05-04T23:13:22+0000',
#   'With unemployment below 4 percent for the first time since 2000, the '
#   'recovery’s duration is remarkable, but lagging pay remains a riddle.'],
#  ['2018-05-03T22:18:55+0000',
#   'Democrats have their eye on flipping a congressional seat in a district '
#   'near Seattle, in a state that has more at stake in a trade war than any '
#   'other.'],
#  ['2018-05-02T18:54:13+0000',
#   'The consultant, which said it would cease most operations in the United '
#   'States and Britain, relied on Facebook data to profile and target voters '
#   'during the 2016 campaign.'],
#  ['2018-05-02T18:22:46+0000',
#   'Brazil accused the U.S. of breaking off negotiations over the steel and '
#   'aluminum tariffs last week, seeming to contradict the White House version '
#   'of events.'],
#  ['2018-05-02T19:21:33+0000',
#   'An executive order is being considered to raise the barrier for sales of '
#   'equipment in the United States by companies like Huawei and ZTE, people '
#   'briefed on the discussions said.'],
#  ['2018-05-02T19:55:03+0000',
#   'The Trump administration is headed to China to present the country with '
#   'tough demands on trade, but what may soon become most apparent is how '
#   'divided American officials are.'],
#  ['2018-04-30T23:59:12+0000',
#   'CBS News made noises about pulling out. A pledge to reimagine the dinner '
#   'eased the network’s concerns.'],
#  ['2018-05-01T00:02:05+0000',
#   'President Trump will give Canada, Mexico and the European Union another '
#   '30-day reprieve from steel and aluminum tariffs, delaying punishing levies '
#   'on key allies.'],
#  ['2018-04-29T21:40:01+0000',
#   'The state’s Democratic primary raises the question: Who has the truest '
#   'claim to progressivism in 2018, when both candidates can credibly grab at '
#   'the label?'],
#  ['2018-04-28T15:30:04+0000',
#   'G.O.P. leaders and White House aides are trying to prepare the president '
#   'for trouble in House and Senate races. But he is rejecting their grim '
#   'prognoses and wants to start campaigning.'],
#  ['2018-04-27T01:28:22+0000',
#   'The resignation of the Rev. Patrick J. Conroy, which was requested by '
#   'Speaker Paul D. Ryan, has lawmakers from both parties demanding answers.'],
#  ['2018-04-25T23:51:06+0000',
#   'Republicans may balk at some of the provisions, while Democrats, who have '
#   'long criticized the existing deal, may argue that the president’s changes '
#   'do not go far enough.'],
#  ['2018-04-25T03:14:26+0000',
#   'The former state senator benefited from more than $1 million in outside '
#   'spending by Republican groups determined to avoid repeats of losses in '
#   'Alabama and Pennsylvania.'],
#  ['2018-04-24T23:34:35+0000',
#   'Facebook shuffled its ranks in Washington as it confronts pressure from '
#   'lawmakers over data privacy, election interference, misinformation and '
#   'other issues.'],
#  ['2018-04-22T20:24:34+0000',
#   'Many of Amazon’s opponents have struggled for years to be heard. Now they '
#   'have the country’s most powerful bullhorn — President Trump — on their '
#   'side.'],
#  ['2018-04-21T21:48:28+0000',
#   'The update of an existing pact will lift trade in dairy, digital goods and '
#   'other products, and sends a message that some of America’s trading partners '
#   'are moving on.'],
#  ['2018-04-21T15:06:07+0000',
#   'Democratic leaders are intervening aggressively in California, where the '
#   'state’s unusual voting system could undercut their chances in crowded '
#   'congressional races.'],
#  ['2018-04-21T02:30:29+0000',
#   'Mr. Sanders, the Vermont senator and 2016 presidential candidate, also '
#   'criticized national Democrats for not doing more to support liberal '
#   'candidates.'],
#  ['2018-04-18T23:05:15+0000',
#   'China’s proposed tariffs on soybeans would hit hard in Iowa, Kansas, '
#   'Missouri, North Dakota and other states with highly competitive House and '
#   'Senate races.'],
#  ['2018-04-18T22:09:59+0000',
#   'One of the technology industry’s brightest stars finds its business under '
#   'fire in two countries. Beijing seeks new concessions to seal a major deal.'],
#  ['2018-04-17T22:09:54+0000',
#   'A survey shows strong support for President Trump’s tariff moves among his '
#   'backers, but not so much among those whose votes could be in play.'],
#  ['2018-04-17T20:08:08+0000',
#   'The Fox News host has criticized the raid on President Trump’s lawyer '
#   'multiple times — but he never disclosed his connection to the lawyer.'],
#  ['2018-04-17T15:54:35+0000',
#   'To protect the public without overreacting, the issue for legislators and '
#   'regulators to weigh is how much the data-driven ecosystem is worth to us.'],
#  ['2018-04-17T13:00:04+0000',
#   'The world economy is looking brighter than it has in years, but as leaders '
#   'converge on Washington this week, they will have one eye on potential '
#   'disruptions from the White House.'],
#  ['2018-04-16T22:08:11+0000',
#   'Republicans hoped to make their $1.5 trillion overhaul the centerpiece of '
#   'the 2018 midterm elections. But Americans, including President Trump, have '
#   'lost interest.'],
#  ['2018-04-16T19:14:46+0000',
#   'Richard Clarida, a former Treasury official, is not expected to veer from '
#   'the Fed’s gradual approach to raising interest rates.'],
#  ['2018-04-15T19:40:07+0000',
#   'Maurice R. Greenberg wants to curb the Martin Act, the regulation that led '
#   'to his ouster at A.I.G., as well as other state securities rules.'],
#  ['2018-04-15T14:47:02+0000',
#   'President Trump on Sunday delivered a series of scathing tweets ahead of '
#   'the former F.B.I. director James Comey’s appearance on ABC News.'],
#  ['2018-06-12T23:56:03+0000',
#   'The Justice Department never should have opposed the AT&T-Time Warner '
#   'merger. Now a chastened government might not intervene when it should.'],
#  ['2018-06-28T19:11:44+0000',
#   'The social media companies, under fire for allowing misinformation, '
#   'unveiled new tools meant to improve transparency before the midterm '
#   'elections.'],
#  ['2018-06-28T10:21:29+0000',
#   'Justice Anthony Kennedy will retire, which means companies can expect '
#   'corporate cases to go their way for a generation.'],
#  ['2018-06-29T15:18:41+0000',
#   'Chinese companies are steering less money into its Belt and Road '
#   'Initiative, as top officials ask whether borrowers will be able to repay '
#   'loans.'],
#  ['2018-06-28T17:09:48+0000',
#   'In a rare move, French authorities charged Lafarge SA, one of France’s '
#   'biggest companies, with financing the Islamic State and endangering the '
#   'lives of its employees.'],
#  ['2018-06-23T16:27:54+0000',
#   'Khalid al-Falih, the Saudi energy minister, said that his country had '
#   'capacity to spare and needed to be mindful of its customers’ interests.'],
#  ['2018-06-25T12:17:28+0000',
#   'The iconic motorcycle manufacturer said that the move was the “only '
#   'sustainable option” to maintain its business in Europe, an increasingly '
#   'vital market.'],
#  ['2018-06-22T00:17:28+0000',
#   'European leaders agreed to a plan that would finally take Athens off '
#   'financial life support, effectively declaring an end to a crisis that '
#   'nearly wrecked the euro.'],
#  ['2018-06-20T23:46:54+0000',
#   'The publisher American Media has been thrust into a federal inquiry '
#   'involving Michael D. Cohen, President Trump’s onetime top lieutenant.'],
#  ['2018-06-24T22:22:26+0000',
#   'The local Communist Party chief has turned to yoga to bring health and '
#   'vitality to a fading, remote hamlet. Some tourist money would be welcome, '
#   'too.'],
#  ['2018-06-21T19:13:24+0000',
#   'The European counterattack, a response to U.S. measures on steel and '
#   'aluminum, adds another front to a trade war that has engulfed allies and '
#   'adversaries around the world.'],
#  ['2018-06-19T10:47:52+0000',
#   'The Chinese telecom giant fears U.S. skepticism over the security of its '
#   'products will spread to countries that have long been dependable '
#   'customers.'],
#  ['2018-06-22T11:15:29+0000',
#   'The shift effectively ends a deal that had more than doubled prices and '
#   'raised revenues for oil producers, but that drew the ire of President '
#   'Trump.'],
#  ['2018-06-20T17:02:47+0000',
#   'Cooperation between several longtime rivals has helped increase oil prices '
#   'in recent months. But that coordination now looks to be at risk.'],
#  ['2018-06-22T09:00:13+0000',
#   'The fortunes of the largest United States banks have changed remarkably '
#   'over the past decade. So is it time to loosen regulation?'],
#  ['2018-06-20T09:59:38+0000',
#   'Business leaders have spoken out about the separation of migrant children '
#   'from their families at U.S. borders.'],
#  ['2018-06-22T05:38:52+0000',
#   'Micron, an American chip maker, says its designs were swiped to help a new '
#   'Chinese plant. Washington sees a larger pattern, fueling tensions with '
#   'Beijing.'],
#  ['2018-06-19T22:03:50+0000',
#   'Lloyd Blankfein said it’s easy to criticize the administration for '
#   'separating immigrant families, but such issues are rarely matters of “right '
#   'against wrong.”'],
#  ['2018-06-19T20:41:54+0000',
#   'Steve Levitan, the creator of “Modern Family,” and the film director Paul '
#   'Feig each expressed disgust with how the news network’s coverage of the '
#   'Trump administration’s border security policy.'],
#  ['2018-06-20T02:20:09+0000',
#   'European officials are eager to paint Greece as a comeback story. But '
#   'troubles in nearby Italy show that the euro’s issues have not been laid to '
#   'rest.'],
#  ['2018-06-19T16:15:02+0000',
#   'The administration, threatening tariffs on as much as $450 billion worth of '
#   'goods, believes Beijing has more to lose. Companies, investors and markets '
#   'are increasingly worried.'],
#  ['2018-06-19T23:24:28+0000',
#   'Fewer people are seeking and receiving Social Security disability benefits, '
#   'reversing a long trend that had worried lawmakers about fraud and abuse.'],
#  ['2018-06-18T17:41:19+0000',
#   'Caught in the trade fight between Washington and Beijing, Tim Cook, Apple’s '
#   'chief executive, has become something of an envoy while trying to protect '
#   'the company’s business in China.'],
#  ['2018-04-12T17:56:50+0000',
#   'The 44 senators who questioned Mark Zuckerberg on Tuesday have one thing in '
#   'common: They’re all his users.'],
#  ['2018-04-12T17:51:38+0000',
#   'The president said his advisers would look into rejoining a trade deal he '
#   'withdrew from last year, as the White House tries to help farmers who will '
#   'be hurt by its trade measures.'],
#  ['2018-06-16T14:36:20+0000',
#   'As President Trump intensifies trade hostilities, the potential for '
#   'conflict has begun to disrupt business, sowing worries about global '
#   'economic growth.'],
#  ['2018-06-14T12:00:04+0000',
#   'Senators Marco Rubio and Elizabeth Warren offered bipartisan legislation '
#   'that would end a practice that critics say prevents those who defaulted on '
#   'loans from paying what they owe.'],
#  ['2018-04-11T23:44:45+0000',
#   'Facebook’s chief executive, Mark Zuckerberg, faced harsher critics in the '
#   'House during his second day of congressional hearings. But there is little '
#   'consensus about how to regulate Silicon Valley.'],
#  ['2018-06-13T11:54:51+0000',
#   'Investors worry that American lawmakers will stop a White House agreement '
#   'that would allow the Chinese company to resume buying U.S. technology.'],
#  ['2018-06-14T12:38:31+0000',
#   'Goldman Sachs earned $600 million in fees helping sell bonds for the state '
#   'investment fund at the center of a scandal that helped put the country '
#   'deeply in debt.'],
#  ['2018-06-14T00:03:45+0000',
#   'The Fed chairman said the numbers showed no signs that trade tensions are '
#   'dampening the economy. Was that the right approach?'],
#  ['2018-06-14T13:11:00+0000',
#   'The country’s focus on reducing its debt has left small businesses facing a '
#   'credit crunch, and the economy appears to be slowing.'],
#  ['2018-06-12T00:15:37+0000',
#   'In 454 pages made public by Congress on Monday, Facebook provided responses '
#   'to more than 2,000 questions from lawmakers over its policies.'],
#  ['2018-06-12T13:21:33+0000',
#   'Wall Street has convinced itself that corporate earnings will be strong '
#   'enough carry the stock market through President Trump’s trade tumult.'],
#  ['2018-06-12T08:52:32+0000',
#   'It’s the ultimate long shot, but a few companies and investors are '
#   'preparing for a time when East Asia’s last growth market opens up to '
#   'outsiders.'],
#  ['2018-06-12T00:48:04+0000',
#   'President Trump’s top economic adviser is at Walter Reed Medical Center and '
#   'is expected to fully recover, the White House said.'],
#  ['2018-06-12T03:07:23+0000',
#   'Nearly 80 transactions in 2017 totaled $147 million, financial disclosures '
#   'showed. Ethics experts have said the activity could raise questions of '
#   'possible conflicts of interest.'],
#  ['2018-06-11T19:21:52+0000',
#   'Mr. Navarro, a top trade adviser to President Trump, said there was a '
#   '“special place in hell” for Canada’s prime minister as a divisive trade '
#   'fight continues.'],
#  ['2018-06-10T23:48:58+0000',
#   'A ratcheting up of tensions between the media and government, continuing a '
#   'crackdown on leaks that ramped up in the Obama years.'],
#  ['2018-04-10T17:57:53+0000',
#   'The social network revealed that the harvesting of people’s Facebook data '
#   'was not limited to public profile information.'],
#  ['2018-04-10T19:58:54+0000',
#   'We fact checked what Facebook’s chief executive is telling lawmakers in '
#   'congressional hearings about the social network’s responsibilities to users '
#   'and more.'],
#  ['2018-06-09T00:10:38+0000',
#   'The Trump administration took possession of a journalist’s email and phone '
#   'records as part of a leak investigation.'],
#  ['2018-06-08T10:26:36+0000',
#   'As President Trump attends the Group of 7 summit, it is important to '
#   'understand how much has so far gone his way. But the real test is '
#   'approaching.'],
#  ['2018-04-06T18:00:34+0000',
#   'As Mark Zuckerberg, the company’s chief executive, prepares to testify '
#   'before Congress, the company also said it supported the proposed Honest Ads '
#   'Act.'],
#  ['2018-06-07T09:00:05+0000',
#   'As bank shares and bonds plunge in Italy, hedge funds are looking to cash '
#   'in.'],
#  ['2018-06-07T16:56:22+0000',
#   'A deal announced by the Trump administration makes ZTE, a Chinese '
#   'electronics maker, a focal point of U.S.-Chinese trade relations.'],
#  ['2018-06-05T09:00:11+0000',
#   'Mr. Gillespie, a longtime lobbyist and former Republican political '
#   'candidate, will become chairman of the communications firm’s public affairs '
#   'arm.'],
#  ['2018-04-09T22:10:43+0000',
#   'Women are playing leading roles across the political spectrum in the state, '
#   'with Democrats hoping to flip the Arizona legislature and Republicans '
#   'fielding strong female candidates at all levels.'],
#  ['2018-05-29T13:15:43+0000',
#   'Italy has not had a new government since holding elections in March. But in '
#   'the past week, the country’s politics exhibited a new level of '
#   'unpredictability.'],
#  ['2018-06-05T09:54:33+0000',
#   'Proposals from investors seeking to shake up Tesla’s board and force Mr. '
#   'Musk to give up one of his two top positions were rejected.'],
#  ['2018-06-06T02:27:00+0000',
#   'Greece is reaching a pivotal moment as it prepares to exit financial '
#   'bailouts. Greeks who left the country are skeptical.'],
#  ['2018-06-04T20:15:05+0000',
#   'Mr. Schultz’s decision to retire from Starbucks, a plan he says he '
#   'privately outlined to the board a year ago, could stoke speculation that he '
#   'is considering a move into politics.'],
#  ['2018-04-09T16:35:37+0000',
#   'The meetings were part of an effort by Mr. Zuckerberg to get ahead of a '
#   'week of intense scrutiny for him and his company, Facebook.'],
#  ['2018-05-24T17:00:04+0000',
#   'Facebook said it would add a “paid for” label and give information on costs '
#   'and target audiences. Twitter’s changes include restrictions on who can run '
#   'the ads and rules for campaign accounts.'],
#  ['2018-04-09T09:00:07+0000',
#   'The United States is Europe’s biggest trading partner, but China is closing '
#   'in fast. If a trade war breaks out, neutrality may not be an option.'],
#  ['2018-06-02T16:16:17+0000',
#   'Facing a crisis of affordability, officials are trying to reduce real '
#   'estate demand through a package of tax measures, some aimed at foreign '
#   'buyers.'],
#  ['2018-06-01T10:09:41+0000',
#   'The day the president’s metals tariffs went into effect, the unemployment '
#   'rate fell to an 18 year low. But can this situation last?'],
#  ['2018-05-31T14:59:16+0000',
#   'The decision will lower trade barriers on an eclectic range of imports, but '
#   'on few American goods.'],
#  ['2018-05-31T20:45:14+0000',
#   'Wall Street seems to have decided that the companies will prevail in their '
#   'antitrust fight with the Justice Department. That’s no sure thing.'],
#  ['2018-05-31T14:39:48+0000',
#   'The allegation undercuts the importance Apple has placed on privacy and '
#   'encrypted communication, and highlights the gatekeeper role the company '
#   'plays with its App Store.'],
#  ['2018-05-30T15:30:19+0000',
#   'The Fed proposed loosening the Volcker Rule, which prevents banks from '
#   'trading with depositors’ money. The move is expected to give banks more '
#   'room for complex trades.'],
#  ['2018-04-06T09:00:11+0000',
#   'Mr. Scaramucci, the voluble former White House communications director, is '
#   'a co-executive producer of HBO’s “Paterno.” It started with an acquaintance '
#   'made on an Oliver Stone film.'],
#  ['2018-04-06T03:16:21+0000',
#   'The Vermont senator, who drew slim support from African-Americans in his '
#   '2016 presidential bid, is now trying to fix that vulnerability as he '
#   'considers another run in 2020.'],
#  ['2018-04-05T23:54:16+0000',
#   'After months of stalemate, American negotiators are eager for quick '
#   'progress on the North American trade deal.'],
#  ['2018-05-25T05:00:10+0000',
#   'Major tech companies took steps to prevent foreign meddling online before '
#   'voters in Ireland cast ballots on Friday. Here’s how those efforts are '
#   'working out.'],
#  ['2018-04-05T18:58:55+0000',
#   'Mick Mulvaney, who is trying to rein in the Consumer Financial Protection '
#   'Bureau, awarded large pay increases to two recent recruits.'],
#  ['2018-05-24T02:58:02+0000',
#   'The move comes as United States and European leaders grow increasingly '
#   'skeptical of Chinese deals, often citing concerns about national security.'],
#  ['2018-05-23T18:37:15+0000',
#   'A federal judge in Manhattan ruled on Wednesday that President Trump’s '
#   'practice of blocking Twitter users who criticize him is unconstitutional.'],
#  ['2018-05-24T00:13:41+0000',
#   'The Trump administration is pushing a rule, first proposed under President '
#   'Obama, to transfer and streamline oversight of commercial firearms '
#   'exports.'],
#  ['2018-05-23T23:48:53+0000',
#   'President Trump has instructed the commerce secretary to investigate '
#   'whether imported autos pose a threat to national security, a move that '
#   'could further strain relations with global allies.'],
#  ['2018-04-04T23:27:59+0000',
#   'President Trump says Amazon costs the U.S.P.S. billions of dollars. But the '
#   'available evidence is far less certain, and some of it suggests the '
#   'opposite.'],
#  ['2018-04-05T00:31:28+0000',
#   'If the tariffs stand, along with China’s retaliatory moves, they could '
#   'damage industries that have relied on a global supply chain for their '
#   'recovery.'],
#  ['2018-05-23T05:00:06+0000',
#   'France has quickly become one of the hottest destinations in Europe for '
#   'technology investment, but it faces big challenges in its mission to become '
#   'a leader.'],
#  ['2018-05-22T16:14:11+0000',
#   'The bipartisan legislation will now head to President Trump, leaving fewer '
#   'than 10 big banks subject to stricter post-crisis oversight.'],
#  ['2018-05-22T04:01:04+0000',
#   'Facebook’s chief executive is expected to strike a conciliatory tone about '
#   'user data on Tuesday when he speaks to members of the European Parliament.'],
#  ['2018-05-22T01:13:59+0000',
#   'President Trump’s negotiating playbook is by now pretty obvious: Make big '
#   'demands, thump your chest and claim victory. But some of his talk on China '
#   'has a whiff of desperation.'],
#  ['2018-04-03T17:13:32+0000',
#   'An analysis of corporate philanthropy finds that donations to causes '
#   'affiliated with politicians look a lot like lobbying.'],
#  ['2018-04-03T22:33:39+0000',
#   'The Trump administration released a list of Chinese goods that it will '
#   'subject to tariffs, including electronics, iron and steel plates, engines '
#   'and optical scanners.'],
#  ['2018-05-20T20:05:01+0000',
#   'Also, a public comment period on proposed tariffs on Chinese imports ends, '
#   'and Disney tries to kick a Memorial Day slump with a new “Star Wars” '
#   'movie.'],
#  ['2018-05-19T15:06:24+0000',
#   'A country taps its past as it leads the way on one of the most pressing '
#   'issues facing modern democracies: how to regulate the world’s biggest '
#   'social network.'],
#  ['2018-05-16T20:38:11+0000',
#   'The rare victory for Democrats is sure to be short-lived in Congress, but '
#   'they plan to use the issue to get young voters engaged in midterm '
#   'elections.'],
#  ['2018-05-16T00:34:31+0000',
#   'The coordinator organized the defense of government computer networks and '
#   'critical infrastructure.'],
#  ['2018-05-14T11:45:41+0000',
#   'The U.S. punishment of one of China’s biggest electronics companies and the '
#   'American president’s surprise offer come at a complicated time.'],
#  ['2018-05-13T20:55:24+0000',
#   'The metal tariffs were supposed to protect manufacturers. But they are also '
#   'delaying investment, expansion and hiring until companies know where they '
#   'stand.'],
#  ['2018-05-13T16:36:58+0000',
#   'The company, which was barred from using American components, said it had '
#   'halted “major operating activities.”'],
#  ['2018-03-30T21:31:00+0000',
#   'What the journey of a Union Pacific locomotive reveals about Trump’s plans '
#   'for the North American economy.'],
#  ['2018-03-30T09:00:08+0000',
#   'Even though Mr. Trump still takes potshots at Amazon, the industry’s '
#   'relationship with the White House is shifting as tech companies find some '
#   'common ground with the president.'],
#  ['2018-03-30T00:14:04+0000',
#   'The network realized it was leaving some viewers behind — and put into '
#   'effect a plan that brought back a working-class sitcom.'],
#  ['2018-05-09T16:56:54+0000',
# ...
#   'last month, but all eyes were on November, when Green leaders say they’ll '
#   'field at least 224 candidates.'],
#  ['2018-08-01T16:16:33+0000',
#   'The administration said it would consider raising proposed tariffs on $200 '
#   'billion of Chinese products to 25 percent from 10 percent as China’s '
#   'currency declines.'],
#  ['2018-08-01T17:43:30+0000',
#   'The company’s chairman and chief executive is a rare business leader who '
#   'applauds President Trump’s protectionist approach to trade.'],
#  ['2018-07-30T21:20:57+0000',
#   'Monster-themed pornography does exist. But Denver Riggleman, a Republican, '
#   'said his writing on Bigfoot has not been pornographic.'],
#  ['2018-07-29T09:00:09+0000',
#   'The actress-turned-candidate for governor is trying to persuade skeptical '
#   'New York Democrats to see beyond her political inexperience, as some did '
#   'with Alexandria Ocasio-Cortez.'],
#  ['2018-07-13T09:00:09+0000',
#   'Tech for Campaigns, a volunteer network of people with day jobs at '
#   'companies like Google, is trying to drag Democratic campaigns into the '
#   'digital age.'],
#  ['2018-07-13T21:00:11+0000',
#   'The Commerce Department said the Chinese telecommunications firm had met '
#   'the terms of a settlement deal and was no longer subject to an order that '
#   'had pushed it to the brink of financial collapse.'],
#  ['2018-07-13T10:11:01+0000',
#   'The president has said that Britain’s plan for a soft Brexit mean he’s '
#   'unlikely to negotiate a new trade deal with the nation.'],
#  ['2018-07-10T22:09:16+0000',
#   'The Information Commissioner’s Office said it was fining Facebook 500,000 '
#   'pounds — the maximum allowed — for letting Cambridge Analytica harvest '
#   'users’ information without their consent.'],
#  ['2018-07-27T21:08:56+0000',
#   'Tying recent growth to his policy moves, the president offered broad '
#   'pronouncements and a litany of statistics. Some were well founded, others '
#   'less so.'],
#  ['2018-07-13T15:32:47+0000',
#   'The Federal Reserve’s semiannual Monetary Policy Report suggests that '
#   'policymakers will continue with their plan to raise rates a total of four '
#   'times in 2018.'],
#  ['2018-07-25T09:00:11+0000',
#   'Mr. Kemp won the Republican nomination for Georgia governor on Tuesday '
#   'night. We analyzed his acceptance speech.'],
#  ['2018-07-24T22:59:58+0000',
#   'Private-sector optimism is widespread, with risks from tariffs, deficits '
#   'and global tensions outweighed by profit-plumping tax cuts and '
#   'deregulation.'],
#  ['2018-07-26T23:17:17+0000',
#   'Second-quarter economic growth could register above 4 percent. But the '
#   'figure may have been driven by one-time factors that will be offset later.'],
#  ['2018-07-26T12:26:53+0000',
#   'The errors emerged as part of a test by the A.C.L.U. that compared the '
#   'photos of all federal lawmakers against a database of 25,000 publicly '
#   'available mug shots.'],
#  ['2018-07-10T10:04:57+0000',
#   'Trump’s new choice, Brett Kavanaugh, would make the Supreme Court more '
#   'conservative. Here’s what his confirmation could mean for business.'],
#  ['2018-07-09T10:00:04+0000',
#   'A new book by the journalist James Crabtree argues that the current regime '
#   'of the superrich can blossom into a Progressive Era that leaves behind '
#   'inequality and crony capitalism.'],
#  ['2018-07-22T21:07:03+0000',
#   'The Fox News anchor follows his aggressive interview of the Russian '
#   'president with a vacation — to St. Petersburg.'],
#  ['2018-07-10T09:00:13+0000',
#   'The country is sliding toward crisis as its currency plunges, corporate '
#   'debts increase and an autocratic president undermines faith in '
#   'institutions.'],
#  ['2018-07-20T22:55:39+0000',
#   'Ms. Guilfoyle, who recently revealed that she is dating Donald Trump Jr., '
#   'had been at the network for 12 years.'],
#  ['2018-07-09T15:43:49+0000',
#   'Beijing’s retaliatory tariffs make American soy pricier. But the country’s '
#   'huge demand for oil and animal feed makes it tough to stop importing '
#   'overnight.'],
#  ['2018-07-19T17:16:35+0000',
#   'Radio Free Europe/Radio Liberty is mostly restricted by law from promoting '
#   'its content in the United States except on request.'],
#  ['2018-07-06T13:00:03+0000',
#   'Facebook’s bad news cycle doesn’t seem to be coming to an end anytime soon, '
#   'with broadened federal investigations and organizations still using the '
#   'social network to foment noise.'],
#  ['2018-07-20T17:16:40+0000',
#   'Party officials voted unanimously on Friday to select Charlotte, which '
#   'approved the gathering amid concerns over protests and damage to its '
#   'reputation.'],
#  ['2018-07-19T22:27:21+0000',
#   'A brief list of the times the president has invoked a pet locution of '
#   'autocrats.'],
#  ['2018-07-05T21:01:47+0000',
#   'Comments from the Trump administration suggest that it may not view the '
#   'independence of the Fed as sacred.'],
#  ['2018-07-19T23:00:37+0000',
#   'The Sinclair Broadcast Group’s plan to create a broadcasting behemoth that '
#   'it hoped would rival Rupert Murdoch’s Fox News appears to be coming to an '
#   'end.'],
#  ['2018-07-18T20:08:07+0000',
#   'The TV operator said it would sell off two stations through an independent '
#   'trust. That was not enough to satisfy the Federal Communications Commission '
#   'chairman’s concerns.'],
#  ['2018-07-05T16:47:52+0000',
#   'The Trump administration began imposing tariffs on $34 billion worth of '
#   'Chinese products on Friday, setting up a trade clash between the world’s '
#   'two largest economies.'],
#  ['2018-07-05T13:04:16+0000',
#   'Lawmakers rejected a bill backed by news outlets and music publishers to '
#   'restrict the use of their content on platforms like YouTube and Facebook.'],
#  ['2018-07-03T19:39:42+0000',
#   'Tatiana R. Martins, the head of the public corruption unit in the United '
#   'States attorney’s office in Manhattan, will join the law firm Davis Polk as '
#   'a partner.'],
#  ['2018-07-18T00:27:00+0000',
#   'The proposed accord with the federal government would have avoided a '
#   'decision that could expose parent companies to liability for violations by '
#   'franchisees.'],
#  ['2018-07-15T09:00:06+0000',
#   'As many top Democrats eye a run for president in 2020, Elizabeth Warren has '
#   'all but announced her candidacy, while Joe Biden is planning to campaign up '
#   'to four days a week this fall for midterm candidates.'],
#  ['2018-07-01T07:00:04+0000',
#   '“Fox & Friends” and Sean Hannity rack up ratings victories while '
#   'cheerleading for the president, whose approval numbers hit a high point in '
#   'June.'],
#  ['2018-07-13T23:30:46+0000',
#   'Operatives used cryptocurrency to obscure their identities and pay for the '
#   'infrastructure needed to steal emails from Hillary Clinton’s 2016 '
#   'presidential campaign.'],
#  ['2018-07-11T23:36:25+0000',
#   'Under a new rule, superdelegates would not be allowed to vote during the '
#   'first ballot of the presidential nominating process, except in '
#   'extraordinary cases like contested conventions.'],
#  ['2018-07-12T21:19:56+0000',
#   'In a letter to the Federal Trade Commission, Edward J. Markey and Richard '
#   'Blumenthal expressed concern that Samba TV wasn’t transparent with viewers '
#   'about data it collected.'],
#  ['2018-07-13T22:59:40+0000',
#   'Fears of an overheated economy could prompt the Federal Reserve to cut '
#   'short a recovery in which incomes have already struggled to gain traction.'],
#  ['2018-10-15T17:52:36+0000',
#   'Over its long history, the retailer has had an influence in some unexpected '
#   'places. '],
#  ['2018-07-02T09:51:12+0000',
#   'Shares in Europe dropped, following Asian markets lower, as investors '
#   'grappled with worsening global trade ties and an escalating rebellion '
#   'against Germany’s leader.'],
#  ['2018-07-06T10:21:05+0000',
#   'While many maintain a defiant tone, Chinese shoppers could get hurt as the '
#   'trade war hurts exports and makes even basic types of food more expensive.'],
#  ['2018-12-05T15:32:33+0000',
#   'OPEC’s gathering in Vienna comes at a tricky time for the oil industry and '
#   'consumers who depend on the world’s largest source of energy.'],
#  ['2018-07-02T21:44:38+0000',
#   'Mr. Ross and his longtime producer, Rhonda Schwartz, are leaving the '
#   'network seven months after he erroneously reported a story involving '
#   'President Trump and the Russia investigation.'],
#  ['2018-07-03T14:34:38+0000',
#   'Dean Baquet, the paper’s executive editor, said Ali Watkins, whose email '
#   'and phone records were seized by the Trump administration, will be moved '
#   'from the Washington bureau to a new beat in New York.'],
#  ['2018-07-03T18:58:34+0000',
#   'L.G.B.T. groups have made strides in recent years as Justice Kennedy '
#   'crafted favorable rulings. A more conservative court could spur new '
#   'challenges.'],
#  ['2018-10-02T12:38:41+0000',
#   'The e-commerce titan is raising hourly pay to $15 an hour in the wake of '
#   'attacks over how it treats workers. But will investors buy it?'],
#  ['2018-07-01T19:08:00+0000',
#   'High school educators across the country have been clamping down on '
#   'students who publish articles on protests, sexuality and other hot-button '
#   'issues.'],
#  ['2018-09-04T10:30:16+0000',
#   'Silicon Valley firms don’t see eye to eye with the government. Will that '
#   'slow down technological progress?'],
#  ['2018-11-16T14:00:01+0000',
#   'The internet retailer took 14 months to decide on a second headquarters. '
#   'Surprise! There will be two of them, and skeptics have plenty to chew on.'],
#  ['2018-08-23T09:00:09+0000',
#   'The cybersecurity company has shifted its attention to detecting '
#   'disinformation and uncovering social media campaigns intended to influence '
#   'politics.'],
#  ['2018-09-25T21:47:10+0000',
#   'USAReally might look like any other fledgling news organization. But some '
#   'cybersecurity experts believe it may be part of a retooled Russian '
#   'propaganda operation.'],
#  ['2018-12-02T23:51:00+0000',
#   'But the compromise reached by President Trump and President Xi Jinping '
#   'offers few promises of policy changes, and it sets a tight deadline of '
#   'March 1.'],
#  ['2018-11-06T22:08:38+0000',
#   'Investigators outlined “a disturbing disregard” of privacy in a broad look '
#   'at online tools used by political campaigns.'],
#  ['2018-09-12T00:21:23+0000',
#   'Two new books, “The Fixer” and “Regulatory Hacking,” explain why disruptive '
#   'start-ups need to anticipate the regulatory reaction of the industry '
#   'interests they threaten.'],
#  ['2018-07-25T13:17:12+0000',
#   'Americans are increasingly aware that some business leaders like to enter '
#   'political debates over complex social issues — but not everybody likes it.'],
#  ['2018-11-22T20:34:59+0000',
#   'For the first time in 20 years, the former anchor did not host NBC’s '
#   'broadcast of the Macy’s Thanksgiving Day Parade. '],
#  ['2018-08-23T19:33:49+0000',
#   'The accounts were linked to the state broadcaster, the company said. The '
#   'news followed similar moves by Facebook and Twitter.'],
#  ['2018-07-04T13:33:22+0000',
#   'Stern Hu, who worked for Rio Tinto, was convicted of corruption and jailed '
#   'in 2010. But many of the tensions that framed his trial have not gone '
#   'away.'],
#  ['2018-12-10T14:46:52+0000',
#   'Mr. Mallya, who turned a family brewing business into a sprawling '
#   'conglomerate, fled to Britain in 2016, facing unpaid bills and accusations '
#   'of fraud in his native country.'],
#  ['2018-09-13T23:02:55+0000',
#   'The agency kicked off a series of hearings on whether its competition and '
#   'consumer protection policies should better reflect new technologies and '
#   'companies.'],
#  ['2018-07-25T09:00:12+0000',
#   'Big tech companies are asking themselves where their responsibilities start '
#   'and stop. Sorting that out will be complicated and may end up increasing '
#   'their power.'],
#  ['2018-08-17T10:16:59+0000',
#   'The Tesla chief told The New York Times that working nonstop to turn the '
#   'company around is taking its toll on him. His directors agree.'],
#  ['2018-09-24T10:06:45+0000',
#   'Comcast beat 21st Century Fox to acquire the British broadcaster Sky with a '
#   '$39 billion bid. It may be paying over the odds.'],
#  ['2018-07-27T13:00:04+0000',
#   'Why the week’s most important technology story involved the tragic slaying '
#   'of a young woman at a train station in San Francisco’s East Bay.'],
#  ['2018-10-19T20:11:02+0000',
#   'Facebook, which owns WhatsApp, is trying to prove it can curb the spread of '
#   'false news. But the app’s design makes it difficult.'],
#  ['2018-12-11T11:40:53+0000',
#   'A Morgan Stanley study suggests that investors think their financing '
#   'decisions are balanced, but in reality they’re skewed.'],
#  ['2018-08-02T10:25:42+0000',
#   'There are still large barriers ahead if the company really does plan to '
#   'launch search and news services in the country.'],
#  ['2018-12-03T12:07:25+0000',
#   'With details scant and officials in both countries mum on the issue of '
#   'American-made autos, industry experts were left guessing as to what the '
#   'president meant.'],
#  ['2018-09-06T10:21:43+0000',
#   'A smooth set of hearings for Facebook and Twitter on Capitol Hill were '
#   'followed by news of a Justice Department investigation over political '
#   'bias.'],
#  ['2018-08-09T11:17:14+0000',
#   'The announcement definitively ends efforts by the Sinclair Broadcast Group '
#   'to create a broadcast giant and potential rival to Rupert Murdoch’s Fox '
#   'News.'],
#  ['2018-07-18T10:03:33+0000',
#   'David Solomon will officially take over from Lloyd Blankfein later this '
#   'year, but the changes he makes at the helm of the firm will be subtle.'],
#  ['2018-09-14T18:07:37+0000',
#   'Two groups in particular — whites without a college degree, and black and '
#   'Hispanic college graduates — have lagged as incomes and wealth have grown.'],
#  ['2018-09-09T23:23:16+0000',
#   'A decade after the financial meltdown, the cloud growing over Silicon '
#   'Valley is a reminder that trust can be awfully hard to regain once it’s '
#   'lost.'],
#  ['2018-09-11T10:25:38+0000',
#   'The crash undermined public trust in financial institutions and the '
#   'government that oversaw them, and helped bring about new, populist '
#   'political movements.'],
#  ['2018-10-11T10:23:43+0000',
#   'Worries about foreign policy, inflation, rising interest rates and '
#   'tightening fiscal policy are all playing into the stock market drop.'],
#  ['2018-10-11T19:28:15+0000',
#   'The conventional wisdom is that a strong economy and stock markets help the '
#   'incumbent party in midterm elections. Research doesn’t bear that out.'],
#  ['2018-08-06T10:25:18+0000',
#   'Some businesses are beginning to steer money toward Democratic lawmakers '
#   'who could take leadership roles after the midterm elections.'],
#  ['2018-07-05T18:11:27+0000',
#   'Economists of many stripes say tariffs invite retaliation. Unilaterally '
#   'lowering trade barriers would be a better approach, some say.'],
#  ['2018-09-28T15:37:21+0000',
#   'New directives betray a mounting anxiety among Chinese leaders that the '
#   'country could be facing a worsening slump as the trade war with the United '
#   'States intensifies.'],
#  ['2018-07-10T13:22:42+0000',
#   'Sun Yian was seen as the country’s way into the huge Chinese tech boom. '
#   'Instead, his disappearance has raised questions about Canada’s eagerness '
#   'for deals.'],
#  ['2018-10-30T19:14:27+0000',
#   'Growth in Italy fell to zero, raising further questions about a government '
#   'spending plan that was based on rosier projections for growth.'],
#  ['2018-09-21T19:28:13+0000',
#   'PayPal will stop processing all payments for the conspiracy website, its '
#   'online store and its subsidiaries.'],
#  ['2018-09-12T22:26:48+0000',
#   'After 22 years at the online magazine, Mr. Weisberg goes into business with '
#   'his longtime friend who wrote “The Tipping Point.”'],
#  ['2018-10-02T10:19:32+0000',
#   'The company also said it would lobby the federal government for a higher '
#   'minimum wage.']]

# %%
news3 = pd.DataFrame({
                    'date': date,
                    'time':t,
                    'abstract':abstract})
news3
# Out:
#             date           time  \
# 0     2018-06-21  22:16:45+0000
# 1     2018-06-22  13:00:01+0000
# 2     2018-06-14  23:49:16+0000
# 3     2018-06-29  18:15:00+0000
# 4     2018-06-27  09:00:14+0000
# ...          ...            ...
# 2015  2018-07-10  13:22:42+0000
# 2016  2018-10-30  19:14:27+0000
# 2017  2018-09-21  19:28:13+0000
# 2018  2018-09-12  22:26:48+0000
# 2019  2018-10-02  10:19:32+0000
#
#                                                abstract
# 0     Glitchy enforcement of a new Facebook politica...
# 1     This week, tech companies weighed in on the se...
# 2     The company introduced new policies in respons...
# 3     Calls to eliminate the agency charged with enf...
# 4     It was a night of rebellious Democrats, who ba...
# ...                                                 ...
# 2015  Sun Yian was seen as the country’s way into th...
# 2016  Growth in Italy fell to zero, raising further ...
# 2017  PayPal will stop processing all payments for t...
# 2018  After 22 years at the online magazine, Mr. Wei...
# 2019  The company also said it would lobby the feder...
#
# [2020 rows x 3 columns]

# %%
def sentiment_analyzer_scores(news):
    sentiment = []
    for sentence in news["abstract"]:
        score = analyser.polarity_scores(sentence)
        sentiment.append(score)
    return sentiment
#     print("{:-<40} {}".format(sentence, str(score)))

# %%
news3["sentiment_score"] = sentiment_analyzer_scores(news3)
news3["date"] = pd.to_datetime(news3["date"])
print(type(news3['date'][0]))
news3.sort_values(by='date')

# news2["sentiment_score"]
news3
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#            date           time  \
# 0    2018-06-21  22:16:45+0000
# 1    2018-06-22  13:00:01+0000
# 2    2018-06-14  23:49:16+0000
# 3    2018-06-29  18:15:00+0000
# 4    2018-06-27  09:00:14+0000
# ...         ...            ...
# 2015 2018-07-10  13:22:42+0000
# 2016 2018-10-30  19:14:27+0000
# 2017 2018-09-21  19:28:13+0000
# 2018 2018-09-12  22:26:48+0000
# 2019 2018-10-02  10:19:32+0000
#
#                                                abstract  \
# 0     Glitchy enforcement of a new Facebook politica...
# 1     This week, tech companies weighed in on the se...
# 2     The company introduced new policies in respons...
# 3     Calls to eliminate the agency charged with enf...
# 4     It was a night of rebellious Democrats, who ba...
# ...                                                 ...
# 2015  Sun Yian was seen as the country’s way into th...
# 2016  Growth in Italy fell to zero, raising further ...
# 2017  PayPal will stop processing all payments for t...
# 2018  After 22 years at the online magazine, Mr. Wei...
# 2019  The company also said it would lobby the feder...
#
#                                         sentiment_score
# 0     {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'comp...
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2     {'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compou...
# 3     {'neg': 0.074, 'neu': 0.82, 'pos': 0.107, 'com...
# 4     {'neg': 0.09, 'neu': 0.694, 'pos': 0.216, 'com...
# ...                                                 ...
# 2015  {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'comp...
# 2016  {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'comp...
# 2017  {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'comp...
# 2018  {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'comp...
# 2019  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'comp...
#
# [2020 rows x 4 columns]

# %%
news3.to_csv("sentiment_analysis-2018politics.csv")
# news3.to_csv("sentiment_analysis-2018finance.csv")

# Users⁩ ▸ ⁨jasonree⁩ ▸ ⁨Documents⁩ ▸ ⁨GitHub⁩ ▸ ⁨Project-3⁩
